# %%
from modules import UnlabeledImageDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from modules import UnlabeledImageDataset
#
# File c:\Users\saulr\OneDrive\Documents\GitHub\PatternAnalysis-2025\recognition\S4641797_Proj3\modules.py:1
# ----> 1 import torch
#       2 import torch.nn as nn
#       5 class block:
#
# ModuleNotFoundError: No module named 'torch'
